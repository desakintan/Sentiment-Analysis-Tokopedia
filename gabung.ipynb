# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Daftar nama file Excel yang akan digabungkan
file_names = ["/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Blush On Single 6 g - Blush On - 03 Prom Peach.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Cliquematte Lip Stylo 2 g - Lipstick Matte - 205 Jetsetter.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Color Hypnose Creamy Lipmatte 4.3 g - Lipstick - 07 Temptation.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Color Stick Matte Crayon 2.6 g- Lip Crayon - 105 Skye.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Eye Liner Pencil 1.2 g - Eye Liner - Black Jack.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Eyebrow Pencil 1.14 g - Eye Brow Pencil - Black Lines.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Hydrastay Lite Glow Cushion 15 g - Cushion for Dry Skin - C11 Pink Marble.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Hydrastay Radiant Finishing Powder 8 g - Bedak Tabur.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Hydrastay Smooth Lip Whip 6.5 g - Lip Cream - C11 Suave.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Multifix Matte Blusher 9 g - Blush On Stick - 02 Quickpinker.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Perfect Cover Refill TWC 12 g - Bedak Padat - 03 Maple.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Powerstay 24H Matte Powder Foundation - W22 Warm Ivory.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Powerstay 24H Weightless Liquid Foundation 40ml - Foundation - W22 Warm Ivory.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Powerstay Demi-Matte Cover Cushion 15 g - C11 Pink Marble.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Powerstay Fix & Matte Makeup Setting Spray 50 ml.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Powerstay Glazed Lock Lip Pigment - D11 POMPOUS 2.0.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Powerstay Total Cover Liquid Concealer 6.5 ml - 02 light to Med.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Powerstay Transferproof Matte Lip Cream 7 g - Lip Cream - B03 Hype.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Silky Smooth Translucent Powder 35 g - Bedak Tabur - 01 Porcelain.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Trivia Eye Shadow 6 g - Eye Shadow Palette - Dolly Crush.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Trivia Eye Shadow 6 g - Eye Shadow Palette - Skycrapping Blu.csv",
              "/content/drive/MyDrive/5. BIG DATA/dataset 500/MAKE OVER Velvet Mattifying Primer 20 ml - Makeup Primer.csv"]

# Membaca setiap file Excel dan menyimpannya sebagai dataframe
dfs = [pd.read_csv(file) for file in file_names]

# Menggabungkan semua dataframe menjadi satu
concatenated_df = pd.concat(dfs, ignore_index=True)

# Menyimpan dataframe hasil penggabungan ke dalam file Excel baru
concatenated_df.to_csv("/content/drive/MyDrive/5. BIG DATA/makeover_produk_500.csv", index=False)

# %%
pip install preprocessor
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for preprocessor: filename=preprocessor-1.1.3-py3-none-any.whl size=4473 sha256=f0990b9c24b559521b9e0097424337459ed1fd84281c333242fdfb6e05410141
#   Stored in directory: /root/.cache/pip/wheels/b6/26/c1/ce3fdf93e63c11019da18dbeec4c09309d3edc5461c2a5fffb
# Successfully built preprocessor
# ...

# %%
pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 11.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import preprocessor as p
import nltk
import regex as re
import pymongo
from datetime import datetime, timedelta
from pymongo import MongoClient
from google.colab import files

# %%
import pandas as pd
from pymongo import MongoClient

# URL koneksi MongoDB Atlas
uri = f"mongodb+srv://desakiintan25:denpasar01@cluster0.hosql1f.mongodb.net/db_make_over_review_raw?retryWrites=true&w=majority"
database_name = 'db_make_over_review_raw_new'

# Koneksi ke MongoDB
client = MongoClient(uri)
database = client[database_name]

# List collection yang ingin diimpor dari database
collections = database.list_collection_names()

# Inisialisasi data kosong untuk menyimpan data dari setiap collections
dataframes = []

# Perulangan untuk mengimpor setiap collection dan mengonversinya ke DataFrame pandas
for collection_name in collections:
    collection = database[collection_name]
    # Mengambil semua dokumen (record) dari collection yang sedang diproses
    documents = collection.find()
    # Convert documents ke dalam DataFrame
    df = pd.DataFrame(list(documents))
    dataframes.append(df)

# Menggabungkan kedua dataframe secara vertikal (menambahkan baris baru)
data = pd.concat(dataframes, ignore_index=True)

# Menutup koneksi ke MongoDB
client.close()

# Menyimpan DataFrame ke dalam file CSV
csv_filename = 'data.csv'
data.to_csv(csv_filename, index=False)

print(f"Data telah disimpan dalam file {csv_filename}")
# Out:
# Data telah disimpan dalam file data.csv
